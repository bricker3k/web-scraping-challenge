# %%
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
import os
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests
import pymongo
from flask import Flask, render_template

# %%
#NASA Mars News
#Scrape the NASA Mars News Site and collect the latest News Title and Paragraph Text. Assign the text to variables that you can reference later.

# Example:
#news_title = "NASA's Next Mars Mission to Investigate Interior of Red Planet"
#news_p = "Preparation of NASA's next spacecraft to Mars, InSight, has ramped up this summer, on course for launch next May from Vandenberg Air Force Base in central California -- the first interplanetary launch in history from America's West Coast."

# %%
url ='https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'lxml')

# %%
 soup.find_all('a')
# Out:
# [<a class="nasa_logo" href="http://www.nasa.gov" title="NASA">NASA</a>,
#  <a href="//www.jpl.nasa.gov/" id="jpl_logo" title="Jet Propulsion Laboratory">Jet Propulsion Laboratory</a>,
#  <a href="http://www.caltech.edu/" id="caltech_logo" target="_blank" title="California Institute of Technology">California Institute of Technology</a>,
#  <a class="visuallyhidden focusable" href="#main">Skip Navigation</a>,
#  <a class="menu_button" href="javascript:void(0);" id="menu_button" title="menu button">
#  <span class="menu_icon">menu and search</span>
#  </a>,
#  <a class="nasa_logo" href="http://www.nasa.gov" title=""></a>,
#  <a class="" href="https://www.jpl.nasa.gov/" id="jpl_logo" title="">Jet Propulsion Laboratory</a>,
#  <a class="" href="https://www.jpl.nasa.gov/" id="caltech_logo" title="">California Institute of Technology</a>,
#  <a class="modal_close" id="modal_close" title="close menu">close menu</a>,
#  <a class="menu_button modal_close" href="javascript:void(0);" id="menu_button" title="menu icon">
#  <span class="menu_icon">menu</span>
#  </a>,
#  <a href="/about">about JPL</a>,
#  <a href="/about">about JPL</a>,
#  <a href="/about/exec.php">executive council</a>,
#  <a href="/about/history.php">history</a>,
#  <a href="/about/reports.php">annual reports</a>,
#  <a href="/contact_JPL.php">contact us</a>,
#  <a href="/opportunities/">opportunities</a>,
#  <a href="/events">public events</a>,
#  <a href="/events">overview</a>,
#  <a href="/events/tours/views">tours</a>,
#  <a href="/events/lectures.php">lecture series</a>,
#  <a href="/events/speakers-bureau.php">speakers bureau</a>,
#  <a href="/events/team-competitions.php">team competitions</a>,
#  <a href="/events/special-events.php">special events</a>,
#  <a href="/edu/">education</a>,
#  <a href="/edu/intern/">Intern</a>,
#  <a href="/edu/learn/">Learn</a>,
#  <a href="/edu/teach/">Teach</a>,
#  <a href="/edu/news/">News</a>,
#  <a href="/edu/events/">Events</a>,
#  <a href="https://spaceplace.nasa.gov/menu/play/">Games</a>,
#  <a href="/news">news</a>,
#  <a href="/news">latest news</a>,
#  <a href="/news/presskits.php">press kits</a>,
#  <a href="/news/factsheets.php">fact sheets</a>,
#  <a href="/news/mediainformation.php">media information</a>,
#  <a href="http://blogs.jpl.nasa.gov">blog</a>,
#  <a href="/missions/">missions</a>,
#  <a href="/missions/?type=current">current</a>,
#  <a href="/missions/?type=past">past</a>,
#  <a href="/missions/?type=future">future</a>,
#  <a href="/missions/?type=proposed">proposed</a>,
#  <a href="/missions">all</a>,
#  <a href="/spaceimages">galleries</a>,
#  <a href="/spaceimages">images</a>,
#  <a href="/video">videos</a>,
#  <a href="/infographics">infographics</a>,
#  <a href="/multimedia/audio.php">audio</a>,
#  <a href="/apps/">apps</a>,
#  <a href="/social">Follow JPL</a>,
#  <a addthis:userid="NASAJPL" class="addthis_button_facebook_follow icon at300b" href="http://www.facebook.com/NASAJPL" target="_blank" title="Follow on Facebook"><span class="at-icon-wrapper" style="background-color: rgb(59, 89, 152); line-height: 32px; height: 32px; width: 32px;"><svg alt="Facebook" aria-labelledby="at-svg-facebook-1" class="at-icon at-icon-facebook" role="img" style="width: 32px; height: 32px;" title="Facebook" version="1.1" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><title id="at-svg-facebook-1">Facebook</title><g><path d="M22 5.16c-.406-.054-1.806-.16-3.43-.16-3.4 0-5.733 1.825-5.733 5.17v2.882H9v3.913h3.837V27h4.604V16.965h3.823l.587-3.913h-4.41v-2.5c0-1.123.347-1.903 2.198-1.903H22V5.16z" fill-rule="evenodd"></path></g></svg></span><span class="addthis_follow_label">Facebook</span></a>,
#  <a addthis:userid="NASAJPL" class="addthis_button_twitter_follow icon at300b" href="//twitter.com/NASAJPL" target="_blank" title="Follow on Twitter"><span class="at-icon-wrapper" style="background-color: rgb(29, 161, 242); line-height: 32px; height: 32px; width: 32px;"><svg alt="Twitter" aria-labelledby="at-svg-twitter-2" class="at-icon at-icon-twitter" role="img" style="width: 32px; height: 32px;" title="Twitter" version="1.1" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><title id="at-svg-twitter-2">Twitter</title><g><path d="M27.996 10.116c-.81.36-1.68.602-2.592.71a4.526 4.526 0 0 0 1.984-2.496 9.037 9.037 0 0 1-2.866 1.095 4.513 4.513 0 0 0-7.69 4.116 12.81 12.81 0 0 1-9.3-4.715 4.49 4.49 0 0 0-.612 2.27 4.51 4.51 0 0 0 2.008 3.755 4.495 4.495 0 0 1-2.044-.564v.057a4.515 4.515 0 0 0 3.62 4.425 4.52 4.52 0 0 1-2.04.077 4.517 4.517 0 0 0 4.217 3.134 9.055 9.055 0 0 1-5.604 1.93A9.18 9.18 0 0 1 6 23.85a12.773 12.773 0 0 0 6.918 2.027c8.3 0 12.84-6.876 12.84-12.84 0-.195-.005-.39-.014-.583a9.172 9.172 0 0 0 2.252-2.336" fill-rule="evenodd"></path></g></svg></span><span class="addthis_follow_label">Twitter</span></a>,
#  <a addthis:userid="JPLnews" class="addthis_button_youtube_follow icon at300b" href="http://www.youtube.com/user/JPLnews?sub_confirmation=1" target="_blank" title="Follow on YouTube"><span class="at-icon-wrapper" style="background-color: rgb(205, 32, 31); line-height: 32px; height: 32px; width: 32px;"><svg alt="YouTube" aria-labelledby="at-svg-youtube-3" class="at-icon at-icon-youtube" role="img" style="width: 32px; height: 32px;" title="YouTube" version="1.1" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><title id="at-svg-youtube-3">YouTube</title><g><path d="M13.73 18.974V12.57l5.945 3.212-5.944 3.192zm12.18-9.778c-.837-.908-1.775-.912-2.205-.965C20.625 8 16.007 8 16.007 8c-.01 0-4.628 0-7.708.23-.43.054-1.368.058-2.205.966-.66.692-.875 2.263-.875 2.263S5 13.303 5 15.15v1.728c0 1.845.22 3.69.22 3.69s.215 1.57.875 2.262c.837.908 1.936.88 2.426.975 1.76.175 7.482.23 7.482.15 0 .08 4.624.072 7.703-.16.43-.052 1.368-.057 2.205-.965.66-.69.875-2.262.875-2.262s.22-1.845.22-3.69v-1.73c0-1.844-.22-3.69-.22-3.69s-.215-1.57-.875-2.262z" fill-rule="evenodd"></path></g></svg></span><span class="addthis_follow_label">YouTube</span></a>,
#  <a addthis:userid="nasajpl" class="addthis_button_instagram_follow icon at300b" href="http://instagram.com/nasajpl" target="_blank" title="Follow on Instagram"><span class="at-icon-wrapper" style="background-color: rgb(224, 53, 102); line-height: 32px; height: 32px; width: 32px;"><svg alt="Instagram" aria-labelledby="at-svg-instagram-4" class="at-icon at-icon-instagram" role="img" style="width: 32px; height: 32px;" title="Instagram" version="1.1" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><title id="at-svg-instagram-4">Instagram</title><g><path d="M16 5c-2.987 0-3.362.013-4.535.066-1.17.054-1.97.24-2.67.512a5.392 5.392 0 0 0-1.95 1.268 5.392 5.392 0 0 0-1.267 1.95c-.272.698-.458 1.498-.512 2.67C5.013 12.637 5 13.012 5 16s.013 3.362.066 4.535c.054 1.17.24 1.97.512 2.67.28.724.657 1.337 1.268 1.95a5.392 5.392 0 0 0 1.95 1.268c.698.27 1.498.457 2.67.51 1.172.054 1.547.067 4.534.067s3.362-.013 4.535-.066c1.17-.054 1.97-.24 2.67-.51a5.392 5.392 0 0 0 1.95-1.27 5.392 5.392 0 0 0 1.268-1.95c.27-.698.457-1.498.51-2.67.054-1.172.067-1.547.067-4.534s-.013-3.362-.066-4.535c-.054-1.17-.24-1.97-.51-2.67a5.392 5.392 0 0 0-1.27-1.95 5.392 5.392 0 0 0-1.95-1.267c-.698-.272-1.498-.458-2.67-.512C19.363 5.013 18.988 5 16 5zm0 1.982c2.937 0 3.285.01 4.445.064 1.072.05 1.655.228 2.042.38.514.198.88.437 1.265.822.385.385.624.75.823 1.265.15.387.33.97.38 2.042.052 1.16.063 1.508.063 4.445 0 2.937-.01 3.285-.064 4.445-.05 1.072-.228 1.655-.38 2.042-.198.514-.437.88-.822 1.265-.385.385-.75.624-1.265.823-.387.15-.97.33-2.042.38-1.16.052-1.508.063-4.445.063-2.937 0-3.285-.01-4.445-.064-1.072-.05-1.655-.228-2.042-.38-.514-.198-.88-.437-1.265-.822a3.408 3.408 0 0 1-.823-1.265c-.15-.387-.33-.97-.38-2.042-.052-1.16-.063-1.508-.063-4.445 0-2.937.01-3.285.064-4.445.05-1.072.228-1.655.38-2.042.198-.514.437-.88.822-1.265.385-.385.75-.624 1.265-.823.387-.15.97-.33 2.042-.38 1.16-.052 1.508-.063 4.445-.063zm0 12.685a3.667 3.667 0 1 1 0-7.334 3.667 3.667 0 0 1 0 7.334zm0-9.316a5.65 5.65 0 1 0 0 11.3 5.65 5.65 0 0 0 0-11.3zm7.192-.222a1.32 1.32 0 1 1-2.64 0 1.32 1.32 0 0 1 2.64 0" fill-rule="evenodd"></path></g></svg></span><span class="addthis_follow_label">Instagram</span></a>,
#  <a class="icon all_icon" href="/social">
#  <span>All</span>
#  </a>,
#  <a name="main"></a>,
#  <a class="button fancybox" data-description="This image from the HiRISE instrument on NASA's Mars Reconnaissance Orbiter shows 'Victoria crater,' an impact crater at Meridiani Planum, near the equator of Mars." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/mediumsize/PIA08813_ip.jpg" data-link="/spaceimages/details.php?id=PIA08813" data-title="'Victoria Crater' at Meridiani Planum" id="full_image">
#  					FULL IMAGE
#  				  </a>,
#  <a class="nav_item ir list_icon">
#  				list view
#  			  </a>,
#  <a class="nav_item ir grid_icon">
#  				grid view
#  			  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows an unnamed channel in northern Terra Sabaea." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23741_hires.jpg" data-link="/spaceimages/details.php?id=PIA23741" data-thumbnail="/spaceimages/images/wallpaper/PIA23741-640x350.jpg" data-title="Terra Sabaea Channel">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">March 2, 2020</h3>
#  <div class="item_tease_overlay">Terra Sabaea Channel</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Terra Sabaea Channel" class="thumb" src="/spaceimages/images/wallpaper/PIA23741-640x350.jpg" title="Terra Sabaea Channel"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">March 2, 2020</div>
#  <div class="content_title">
#  										  Terra Sabaea Channel
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows an unnamed channel in northern Terra Sabaea.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a tributary channel of Ares Vallis." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23735_hires.jpg" data-link="/spaceimages/details.php?id=PIA23735" data-thumbnail="/spaceimages/images/wallpaper/PIA23735-640x350.jpg" data-title="Ares Vallis Tributary">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 28, 2020</h3>
#  <div class="item_tease_overlay">Ares Vallis Tributary</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Ares Vallis Tributary" class="thumb" src="/spaceimages/images/wallpaper/PIA23735-640x350.jpg" title="Ares Vallis Tributary"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 28, 2020</div>
#  <div class="content_title">
#  										  Ares Vallis Tributary
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a tributary channel of Ares Vallis.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Minio Vallis. Minio Vallis is just one of many channels that flow northward thru Terra Sirenum to empty into Amazonis Planitia." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23734_hires.jpg" data-link="/spaceimages/details.php?id=PIA23734" data-thumbnail="/spaceimages/images/wallpaper/PIA23734-640x350.jpg" data-title="Minio Vallis">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 27, 2020</h3>
#  <div class="item_tease_overlay">Minio Vallis</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Minio Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23734-640x350.jpg" title="Minio Vallis"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 27, 2020</div>
#  <div class="content_title">
#  										  Minio Vallis
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Minio Vallis. Minio Vallis is just one of many channels that flow northward thru Terra Sirenum to empty into Amazonis Planitia.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a portion of an unnamed channel in Arabia Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23733_hires.jpg" data-link="/spaceimages/details.php?id=PIA23733" data-thumbnail="/spaceimages/images/wallpaper/PIA23733-640x350.jpg" data-title="Arabia Terra Channel">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 26, 2020</h3>
#  <div class="item_tease_overlay">Arabia Terra Channel</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Arabia Terra Channel" class="thumb" src="/spaceimages/images/wallpaper/PIA23733-640x350.jpg" title="Arabia Terra Channel"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 26, 2020</div>
#  <div class="content_title">
#  										  Arabia Terra Channel
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a portion of an unnamed channel in Arabia Terra.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows linear depressions called Mareotis Fossae. They are part of a huge region of graben that comprise Tempe Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23732_hires.jpg" data-link="/spaceimages/details.php?id=PIA23732" data-thumbnail="/spaceimages/images/wallpaper/PIA23732-640x350.jpg" data-title="Mareotis Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 25, 2020</h3>
#  <div class="item_tease_overlay">Mareotis Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Mareotis Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23732-640x350.jpg" title="Mareotis Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 25, 2020</div>
#  <div class="content_title">
#  										  Mareotis Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows linear depressions called Mareotis Fossae. They are part of a huge region of graben that comprise Tempe Terra.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows half of an unnamed crater in Utopia Planitia." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23731_hires.jpg" data-link="/spaceimages/details.php?id=PIA23731" data-thumbnail="/spaceimages/images/wallpaper/PIA23731-640x350.jpg" data-title="Utopia Planitia Crater">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 24, 2020</h3>
#  <div class="item_tease_overlay">Utopia Planitia Crater</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Utopia Planitia Crater" class="thumb" src="/spaceimages/images/wallpaper/PIA23731-640x350.jpg" title="Utopia Planitia Crater"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 24, 2020</div>
#  <div class="content_title">
#  										  Utopia Planitia Crater
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows half of an unnamed crater in Utopia Planitia.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of the tributary channel between Aram Chaos and Ares Vallis." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23710_hires.jpg" data-link="/spaceimages/details.php?id=PIA23710" data-thumbnail="/spaceimages/images/wallpaper/PIA23710-640x350.jpg" data-title="Just a Little Landslide">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 21, 2020</h3>
#  <div class="item_tease_overlay">Just a Little Landslide</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Just a Little Landslide" class="thumb" src="/spaceimages/images/wallpaper/PIA23710-640x350.jpg" title="Just a Little Landslide"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 21, 2020</div>
#  <div class="content_title">
#  										  Just a Little Landslide
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a section of the tributary channel between Aram Chaos and Ares Vallis.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="InSight recently moved its robotic arm closer to its digging device, called the mole, in preparation to push on its top, or back cap." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23622_hires.jpg" data-link="/spaceimages/details.php?id=PIA23622" data-thumbnail="/spaceimages/images/wallpaper/PIA23622-640x350.jpg" data-title="InSight Prepares to Push on the Mole">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 21, 2020</h3>
#  <div class="item_tease_overlay">InSight Prepares to Push on the Mole</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="InSight Prepares to Push on the Mole" class="thumb" src="/spaceimages/images/wallpaper/PIA23622-640x350.jpg" title="InSight Prepares to Push on the Mole"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 21, 2020</div>
#  <div class="content_title">
#  										  InSight Prepares to Push on the Mole
#  										</div>
#  <div class="article_teaser_body">
#  										  InSight recently moved its robotic arm closer to its digging device, called the mole, in preparation to push on its top, or back cap.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This test using an engineering model of the InSight lander here on Earth shows how the spacecraft on Mars will use its robotic arm to press on a digging device, called the mole." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23619_hires.jpg" data-link="/spaceimages/details.php?id=PIA23619" data-thumbnail="/spaceimages/images/wallpaper/PIA23619-640x350.jpg" data-title="Robotic Arm Pushes on a Model of the Mole">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 21, 2020</h3>
#  <div class="item_tease_overlay">Robotic Arm Pushes on a Model of the Mole</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Robotic Arm Pushes on a Model of the Mole" class="thumb" src="/spaceimages/images/wallpaper/PIA23619-640x350.jpg" title="Robotic Arm Pushes on a Model of the Mole"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 21, 2020</div>
#  <div class="content_title">
#  										  Robotic Arm Pushes on a Model of the Mole
#  										</div>
#  <div class="article_teaser_body">
#  										  This test using an engineering model of the InSight lander here on Earth shows how the spacecraft on Mars will use its robotic arm to press on a digging device, called the mole.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows an unnamed channel located in northern Terra Sabaea." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23709_hires.jpg" data-link="/spaceimages/details.php?id=PIA23709" data-thumbnail="/spaceimages/images/wallpaper/PIA23709-640x350.jpg" data-title="Terra Sabaea Channel">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 20, 2020</h3>
#  <div class="item_tease_overlay">Terra Sabaea Channel</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Terra Sabaea Channel" class="thumb" src="/spaceimages/images/wallpaper/PIA23709-640x350.jpg" title="Terra Sabaea Channel"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 20, 2020</div>
#  <div class="content_title">
#  										  Terra Sabaea Channel
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows an unnamed channel located in northern Terra Sabaea.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the surface between Aeolis Planum and Zephyria Planum in Elysium Planitia." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23708_hires.jpg" data-link="/spaceimages/details.php?id=PIA23708" data-thumbnail="/spaceimages/images/wallpaper/PIA23708-640x350.jpg" data-title="Wind Erosion">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 19, 2020</h3>
#  <div class="item_tease_overlay">Wind Erosion</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Wind Erosion" class="thumb" src="/spaceimages/images/wallpaper/PIA23708-640x350.jpg" title="Wind Erosion"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 19, 2020</div>
#  <div class="content_title">
#  										  Wind Erosion
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows the surface between Aeolis Planum and Zephyria Planum in Elysium Planitia.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a cliff face, called Rupes Tenius." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23707_hires.jpg" data-link="/spaceimages/details.php?id=PIA23707" data-thumbnail="/spaceimages/images/wallpaper/PIA23707-640x350.jpg" data-title="Rupes Tenius">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 18, 2020</h3>
#  <div class="item_tease_overlay">Rupes Tenius</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Rupes Tenius" class="thumb" src="/spaceimages/images/wallpaper/PIA23707-640x350.jpg" title="Rupes Tenius"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 18, 2020</div>
#  <div class="content_title">
#  										  Rupes Tenius
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a cliff face, called Rupes Tenius.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Shalbatana Vallis. Shalbatana Vallis is located in Xanthe Terra and is one of many channels that empty into Chryse Planitia." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23706_hires.jpg" data-link="/spaceimages/details.php?id=PIA23706" data-thumbnail="/spaceimages/images/wallpaper/PIA23706-640x350.jpg" data-title="Shalbatana Vallis">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 17, 2020</h3>
#  <div class="item_tease_overlay">Shalbatana Vallis</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Shalbatana Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23706-640x350.jpg" title="Shalbatana Vallis"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 17, 2020</div>
#  <div class="content_title">
#  										  Shalbatana Vallis
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a section of Shalbatana Vallis. Shalbatana Vallis is located in Xanthe Terra and is one of many channels that empty into Chryse Planitia.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Nanedi Valles. Located In Xanthe Terra, the channel system is more than 500 km (310 miles) long." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23705_hires.jpg" data-link="/spaceimages/details.php?id=PIA23705" data-thumbnail="/spaceimages/images/wallpaper/PIA23705-640x350.jpg" data-title="Nanedi Valles">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 14, 2020</h3>
#  <div class="item_tease_overlay">Nanedi Valles</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Nanedi Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23705-640x350.jpg" title="Nanedi Valles"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 14, 2020</div>
#  <div class="content_title">
#  										  Nanedi Valles
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a section of Nanedi Valles. Located In Xanthe Terra, the channel system is more than 500 km (310 miles) long.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a linear feature, part of Labeatis Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23704_hires.jpg" data-link="/spaceimages/details.php?id=PIA23704" data-thumbnail="/spaceimages/images/wallpaper/PIA23704-640x350.jpg" data-title="Labeatis Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 13, 2020</h3>
#  <div class="item_tease_overlay">Labeatis Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Labeatis Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23704-640x350.jpg" title="Labeatis Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 13, 2020</div>
#  <div class="content_title">
#  										  Labeatis Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a linear feature, part of Labeatis Fossae.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the inner rim of an unnamed crater in Terra Sabaea." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23703_hires.jpg" data-link="/spaceimages/details.php?id=PIA23703" data-thumbnail="/spaceimages/images/wallpaper/PIA23703-640x350.jpg" data-title="Dark Slope Streaks">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 12, 2020</h3>
#  <div class="item_tease_overlay">Dark Slope Streaks</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Dark Slope Streaks" class="thumb" src="/spaceimages/images/wallpaper/PIA23703-640x350.jpg" title="Dark Slope Streaks"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 12, 2020</div>
#  <div class="content_title">
#  										  Dark Slope Streaks
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the inner rim of an unnamed crater in Terra Sabaea.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the wind eroded Amazonis Mensa." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23702_hires.jpg" data-link="/spaceimages/details.php?id=PIA23702" data-thumbnail="/spaceimages/images/wallpaper/PIA23702-640x350.jpg" data-title="Amazonis Mensa">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 11, 2020</h3>
#  <div class="item_tease_overlay">Amazonis Mensa</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Amazonis Mensa" class="thumb" src="/spaceimages/images/wallpaper/PIA23702-640x350.jpg" title="Amazonis Mensa"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 11, 2020</div>
#  <div class="content_title">
#  										  Amazonis Mensa
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the wind eroded Amazonis Mensa.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows linear depressions, part of Nili Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23664_hires.jpg" data-link="/spaceimages/details.php?id=PIA23664" data-thumbnail="/spaceimages/images/wallpaper/PIA23664-640x350.jpg" data-title="Nili Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 6, 2020</h3>
#  <div class="item_tease_overlay">Nili Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Nili Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23664-640x350.jpg" title="Nili Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 6, 2020</div>
#  <div class="content_title">
#  										  Nili Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows linear depressions, part of Nili Fossae.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Mamers Valles. The channel is nearly 1000 km long (600 miles)." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23663_hires.jpg" data-link="/spaceimages/details.php?id=PIA23663" data-thumbnail="/spaceimages/images/wallpaper/PIA23663-640x350.jpg" data-title="Mamers Valles">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 5, 2020</h3>
#  <div class="item_tease_overlay">Mamers Valles</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Mamers Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23663-640x350.jpg" title="Mamers Valles"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 5, 2020</div>
#  <div class="content_title">
#  										  Mamers Valles
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a section of Mamers Valles. The channel is nearly 1000 km long (600 miles).
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows channels, part of Nili Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23662_hires.jpg" data-link="/spaceimages/details.php?id=PIA23662" data-thumbnail="/spaceimages/images/wallpaper/PIA23662-640x350.jpg" data-title="Nili Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 4, 2020</h3>
#  <div class="item_tease_overlay">Nili Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Nili Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23662-640x350.jpg" title="Nili Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 4, 2020</div>
#  <div class="content_title">
#  										  Nili Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows channels, part of Nili Fossae.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the central portion of Hephaestus Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23661_hires.jpg" data-link="/spaceimages/details.php?id=PIA23661" data-thumbnail="/spaceimages/images/wallpaper/PIA23661-640x350.jpg" data-title="Hephaestus Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">February 3, 2020</h3>
#  <div class="item_tease_overlay">Hephaestus Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Hephaestus Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23661-640x350.jpg" title="Hephaestus Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">February 3, 2020</div>
#  <div class="content_title">
#  										  Hephaestus Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows the central portion of Hephaestus Fossae.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a portion of the northern flank of Ascraeus Mons." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23660_hires.jpg" data-link="/spaceimages/details.php?id=PIA23660" data-thumbnail="/spaceimages/images/wallpaper/PIA23660-640x350.jpg" data-title="Ascraeus Mons Flank">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 31, 2020</h3>
#  <div class="item_tease_overlay">Ascraeus Mons Flank</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Ascraeus Mons Flank" class="thumb" src="/spaceimages/images/wallpaper/PIA23660-640x350.jpg" title="Ascraeus Mons Flank"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 31, 2020</div>
#  <div class="content_title">
#  										  Ascraeus Mons Flank
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a portion of the northern flank of Ascraeus Mons.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a channel called Auqakuh Vallis." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23659_hires.jpg" data-link="/spaceimages/details.php?id=PIA23659" data-thumbnail="/spaceimages/images/wallpaper/PIA23659-640x350.jpg" data-title="Auqakuh Vallis">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 30, 2020</h3>
#  <div class="item_tease_overlay">Auqakuh Vallis</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Auqakuh Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23659-640x350.jpg" title="Auqakuh Vallis"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 30, 2020</div>
#  <div class="content_title">
#  										  Auqakuh Vallis
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a channel called Auqakuh Vallis.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a small unnamed crater in northern Acidalia Planitia." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23658_hires.jpg" data-link="/spaceimages/details.php?id=PIA23658" data-thumbnail="/spaceimages/images/wallpaper/PIA23658-640x350.jpg" data-title="Acidalia Planitia Crater">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 29, 2020</h3>
#  <div class="item_tease_overlay">Acidalia Planitia Crater</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Acidalia Planitia Crater" class="thumb" src="/spaceimages/images/wallpaper/PIA23658-640x350.jpg" title="Acidalia Planitia Crater"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 29, 2020</div>
#  <div class="content_title">
#  										  Acidalia Planitia Crater
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a small unnamed crater in northern Acidalia Planitia.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a linear depression, part of Cerberus Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23657_hires.jpg" data-link="/spaceimages/details.php?id=PIA23657" data-thumbnail="/spaceimages/images/wallpaper/PIA23657-640x350.jpg" data-title="Cerberus Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 28, 2020</h3>
#  <div class="item_tease_overlay">Cerberus Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Cerberus Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23657-640x350.jpg" title="Cerberus Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 28, 2020</div>
#  <div class="content_title">
#  										  Cerberus Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a linear depression, part of Cerberus Fossae.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows northern Arabia Terra. This region is dissected with numerous unnamed channels of all sizes and complexities." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23656_hires.jpg" data-link="/spaceimages/details.php?id=PIA23656" data-thumbnail="/spaceimages/images/wallpaper/PIA23656-640x350.jpg" data-title="Arabia Terra Channel">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 27, 2020</h3>
#  <div class="item_tease_overlay">Arabia Terra Channel</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Arabia Terra Channel" class="thumb" src="/spaceimages/images/wallpaper/PIA23656-640x350.jpg" title="Arabia Terra Channel"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 27, 2020</div>
#  <div class="content_title">
#  										  Arabia Terra Channel
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows northern Arabia Terra. This region is dissected with numerous unnamed channels of all sizes and complexities.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Naktong Vallis. Located in Terra Sabaea, Naktong Vallis is 670 km long (415 miles)." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23655_hires.jpg" data-link="/spaceimages/details.php?id=PIA23655" data-thumbnail="/spaceimages/images/wallpaper/PIA23655-640x350.jpg" data-title="Naktong Vallis">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 24, 2020</h3>
#  <div class="item_tease_overlay">Naktong Vallis</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Naktong Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23655-640x350.jpg" title="Naktong Vallis"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 24, 2020</div>
#  <div class="content_title">
#  										  Naktong Vallis
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a section of Naktong Vallis. Located in Terra Sabaea, Naktong Vallis is 670 km long (415 miles).
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Tractus Catena, just one of many north/south trending tectonic graben located south and east of Alba Mons." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23654_hires.jpg" data-link="/spaceimages/details.php?id=PIA23654" data-thumbnail="/spaceimages/images/wallpaper/PIA23654-640x350.jpg" data-title="Tractus Catena">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 23, 2020</h3>
#  <div class="item_tease_overlay">Tractus Catena</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Tractus Catena" class="thumb" src="/spaceimages/images/wallpaper/PIA23654-640x350.jpg" title="Tractus Catena"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 23, 2020</div>
#  <div class="content_title">
#  										  Tractus Catena
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Tractus Catena, just one of many north/south trending tectonic graben located south and east of Alba Mons.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows linear depressions which are part of the Cerberus Fossae fracture system." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23653_hires.jpg" data-link="/spaceimages/details.php?id=PIA23653" data-thumbnail="/spaceimages/images/wallpaper/PIA23653-640x350.jpg" data-title="Cerberus Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 22, 2020</h3>
#  <div class="item_tease_overlay">Cerberus Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Cerberus Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23653-640x350.jpg" title="Cerberus Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 22, 2020</div>
#  <div class="content_title">
#  										  Cerberus Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows linear depressions which are part of the Cerberus Fossae fracture system.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows Mangala Valles, a complex channel more than 900km long (560 miles)." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23652_hires.jpg" data-link="/spaceimages/details.php?id=PIA23652" data-thumbnail="/spaceimages/images/wallpaper/PIA23652-640x350.jpg" data-title="Mangala Valles">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 21, 2020</h3>
#  <div class="item_tease_overlay">Mangala Valles</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Mangala Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23652-640x350.jpg" title="Mangala Valles"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 21, 2020</div>
#  <div class="content_title">
#  										  Mangala Valles
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows Mangala Valles, a complex channel more than 900km long (560 miles).
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a portion of Nanedi Valles. This channel is over 500 km long (310 miles) and is located in Xanthe Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23651_hires.jpg" data-link="/spaceimages/details.php?id=PIA23651" data-thumbnail="/spaceimages/images/wallpaper/PIA23651-640x350.jpg" data-title="Nanedi Valles">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 20, 2020</h3>
#  <div class="item_tease_overlay">Nanedi Valles</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Nanedi Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23651-640x350.jpg" title="Nanedi Valles"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 20, 2020</div>
#  <div class="content_title">
#  										  Nanedi Valles
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a portion of Nanedi Valles. This channel is over 500 km long (310 miles) and is located in Xanthe Terra.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the eastern margin of Orcus Patera." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23640_hires.jpg" data-link="/spaceimages/details.php?id=PIA23640" data-thumbnail="/spaceimages/images/wallpaper/PIA23640-640x350.jpg" data-title="Orcus Patera Dark Slope Streaks">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 17, 2020</h3>
#  <div class="item_tease_overlay">Orcus Patera Dark Slope Streaks</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Orcus Patera Dark Slope Streaks" class="thumb" src="/spaceimages/images/wallpaper/PIA23640-640x350.jpg" title="Orcus Patera Dark Slope Streaks"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 17, 2020</div>
#  <div class="content_title">
#  										  Orcus Patera Dark Slope Streaks
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows the eastern margin of Orcus Patera.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="button" href="">
#  				MORE
#  			  </a>,
#  <a href="http://photojournal.jpl.nasa.gov/">
#  <img alt="jpl photojournal" class="thumb" src="/assets/images/content/tmp/images/jpl_photojournal(3x1).jpg"/>
#  </a>,
#  <a href="http://photojournal.jpl.nasa.gov/">
#  				  JPL Photojournal
#  				</a>,
#  <a href="http://www.nasa.gov/multimedia/imagegallery/">
#  <img alt="Great images in NASA" class="thumb" src="/assets/images/content/tmp/images/nasa_images(3x1).jpg"/>
#  </a>,
#  <a href="http://www.nasa.gov/multimedia/imagegallery/">
#  				  Great images in NASA
#  				</a>,
#  <a href="//www.jpl.nasa.gov/news/news.php?feature=7607">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  								  Team CoSTAR, which includes NASA's JPL, Caltech and MIT engineers, placed first.
#  								  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <img alt="CoSTAR member and Caltech graduate student Amanda Bouman operates a robot called Spot" src="//imagecache.jpl.nasa.gov/images/640x350/darpa_amanda-16-640x350.jpg"/>
#  </div>
#  <div class="content_title">
#  								Robots Autonomously Navigate Underground in DARPA Challenge
#  							   </div>
#  </a>,
#  <a href="//www.jpl.nasa.gov/news/news.php?feature=7605">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  								  A batch of new papers summarizes the lander's findings above and below the surface of the Red Planet.
#  								  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <img alt="Artist's concept of NASA's InSight lander" src="//imagecache.jpl.nasa.gov/images/640x350/InSight-Nature-16-640x350.jpg"/>
#  </div>
#  <div class="content_title">
#  								A Year of Surprising Science From NASA's InSight Mars Mission
#  							   </div>
#  </a>,
#  <a href="//www.jpl.nasa.gov/news/news.php?feature=7603">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  								  Engineers have a plan for pushing down on the heat probe, which has been stuck at the Martian surface for a year.
#  								  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <img alt="NASA InSight recently moved its robotic arm" src="//imagecache.jpl.nasa.gov/images/640x350/PIA23622-16-640x350.gif"/>
#  </div>
#  <div class="content_title">
#  								NASA's Mars InSight Lander to Push on Top of the 'Mole'
#  							   </div>
#  </a>,
#  <a class="outline_button dark" href="/news">
#  			  more news
#  			</a>,
#  <a addthis:userid="NASAJPL" class="addthis_button_facebook_follow icon at300b" href="http://www.facebook.com/NASAJPL" target="_blank" title="Follow on Facebook"><span class="at-icon-wrapper" style="background-color: rgb(59, 89, 152); line-height: 32px; height: 32px; width: 32px;"><svg alt="Facebook" aria-labelledby="at-svg-facebook-5" class="at-icon at-icon-facebook" role="img" style="width: 32px; height: 32px;" title="Facebook" version="1.1" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><title id="at-svg-facebook-5">Facebook</title><g><path d="M22 5.16c-.406-.054-1.806-.16-3.43-.16-3.4 0-5.733 1.825-5.733 5.17v2.882H9v3.913h3.837V27h4.604V16.965h3.823l.587-3.913h-4.41v-2.5c0-1.123.347-1.903 2.198-1.903H22V5.16z" fill-rule="evenodd"></path></g></svg></span><span class="addthis_follow_label">Facebook</span></a>,
#  <a addthis:userid="NASAJPL" class="addthis_button_twitter_follow icon at300b" href="//twitter.com/NASAJPL" target="_blank" title="Follow on Twitter"><span class="at-icon-wrapper" style="background-color: rgb(29, 161, 242); line-height: 32px; height: 32px; width: 32px;"><svg alt="Twitter" aria-labelledby="at-svg-twitter-6" class="at-icon at-icon-twitter" role="img" style="width: 32px; height: 32px;" title="Twitter" version="1.1" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><title id="at-svg-twitter-6">Twitter</title><g><path d="M27.996 10.116c-.81.36-1.68.602-2.592.71a4.526 4.526 0 0 0 1.984-2.496 9.037 9.037 0 0 1-2.866 1.095 4.513 4.513 0 0 0-7.69 4.116 12.81 12.81 0 0 1-9.3-4.715 4.49 4.49 0 0 0-.612 2.27 4.51 4.51 0 0 0 2.008 3.755 4.495 4.495 0 0 1-2.044-.564v.057a4.515 4.515 0 0 0 3.62 4.425 4.52 4.52 0 0 1-2.04.077 4.517 4.517 0 0 0 4.217 3.134 9.055 9.055 0 0 1-5.604 1.93A9.18 9.18 0 0 1 6 23.85a12.773 12.773 0 0 0 6.918 2.027c8.3 0 12.84-6.876 12.84-12.84 0-.195-.005-.39-.014-.583a9.172 9.172 0 0 0 2.252-2.336" fill-rule="evenodd"></path></g></svg></span><span class="addthis_follow_label">Twitter</span></a>,
#  <a addthis:userid="JPLnews" class="addthis_button_youtube_follow icon at300b" href="http://www.youtube.com/user/JPLnews?sub_confirmation=1" target="_blank" title="Follow on YouTube"><span class="at-icon-wrapper" style="background-color: rgb(205, 32, 31); line-height: 32px; height: 32px; width: 32px;"><svg alt="YouTube" aria-labelledby="at-svg-youtube-7" class="at-icon at-icon-youtube" role="img" style="width: 32px; height: 32px;" title="YouTube" version="1.1" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><title id="at-svg-youtube-7">YouTube</title><g><path d="M13.73 18.974V12.57l5.945 3.212-5.944 3.192zm12.18-9.778c-.837-.908-1.775-.912-2.205-.965C20.625 8 16.007 8 16.007 8c-.01 0-4.628 0-7.708.23-.43.054-1.368.058-2.205.966-.66.692-.875 2.263-.875 2.263S5 13.303 5 15.15v1.728c0 1.845.22 3.69.22 3.69s.215 1.57.875 2.262c.837.908 1.936.88 2.426.975 1.76.175 7.482.23 7.482.15 0 .08 4.624.072 7.703-.16.43-.052 1.368-.057 2.205-.965.66-.69.875-2.262.875-2.262s.22-1.845.22-3.69v-1.73c0-1.844-.22-3.69-.22-3.69s-.215-1.57-.875-2.262z" fill-rule="evenodd"></path></g></svg></span><span class="addthis_follow_label">YouTube</span></a>,
#  <a addthis:userid="nasajpl" class="addthis_button_instagram_follow icon at300b" href="http://instagram.com/nasajpl" target="_blank" title="Follow on Instagram"><span class="at-icon-wrapper" style="background-color: rgb(224, 53, 102); line-height: 32px; height: 32px; width: 32px;"><svg alt="Instagram" aria-labelledby="at-svg-instagram-8" class="at-icon at-icon-instagram" role="img" style="width: 32px; height: 32px;" title="Instagram" version="1.1" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><title id="at-svg-instagram-8">Instagram</title><g><path d="M16 5c-2.987 0-3.362.013-4.535.066-1.17.054-1.97.24-2.67.512a5.392 5.392 0 0 0-1.95 1.268 5.392 5.392 0 0 0-1.267 1.95c-.272.698-.458 1.498-.512 2.67C5.013 12.637 5 13.012 5 16s.013 3.362.066 4.535c.054 1.17.24 1.97.512 2.67.28.724.657 1.337 1.268 1.95a5.392 5.392 0 0 0 1.95 1.268c.698.27 1.498.457 2.67.51 1.172.054 1.547.067 4.534.067s3.362-.013 4.535-.066c1.17-.054 1.97-.24 2.67-.51a5.392 5.392 0 0 0 1.95-1.27 5.392 5.392 0 0 0 1.268-1.95c.27-.698.457-1.498.51-2.67.054-1.172.067-1.547.067-4.534s-.013-3.362-.066-4.535c-.054-1.17-.24-1.97-.51-2.67a5.392 5.392 0 0 0-1.27-1.95 5.392 5.392 0 0 0-1.95-1.267c-.698-.272-1.498-.458-2.67-.512C19.363 5.013 18.988 5 16 5zm0 1.982c2.937 0 3.285.01 4.445.064 1.072.05 1.655.228 2.042.38.514.198.88.437 1.265.822.385.385.624.75.823 1.265.15.387.33.97.38 2.042.052 1.16.063 1.508.063 4.445 0 2.937-.01 3.285-.064 4.445-.05 1.072-.228 1.655-.38 2.042-.198.514-.437.88-.822 1.265-.385.385-.75.624-1.265.823-.387.15-.97.33-2.042.38-1.16.052-1.508.063-4.445.063-2.937 0-3.285-.01-4.445-.064-1.072-.05-1.655-.228-2.042-.38-.514-.198-.88-.437-1.265-.822a3.408 3.408 0 0 1-.823-1.265c-.15-.387-.33-.97-.38-2.042-.052-1.16-.063-1.508-.063-4.445 0-2.937.01-3.285.064-4.445.05-1.072.228-1.655.38-2.042.198-.514.437-.88.822-1.265.385-.385.75-.624 1.265-.823.387-.15.97-.33 2.042-.38 1.16-.052 1.508-.063 4.445-.063zm0 12.685a3.667 3.667 0 1 1 0-7.334 3.667 3.667 0 0 1 0 7.334zm0-9.316a5.65 5.65 0 1 0 0 11.3 5.65 5.65 0 0 0 0-11.3zm7.192-.222a1.32 1.32 0 1 1-2.64 0 1.32 1.32 0 0 1 2.64 0" fill-rule="evenodd"></path></g></svg></span><span class="addthis_follow_label">Instagram</span></a>,
#  <a class="icon all_icon" href="/social">
#  <span>All</span>
#  </a>,
#  <a href="/about/">About JPL</a>,
#  <a href="https://www.jpl.nasa.gov/jpl2025/vision/">JPL Vision</a>,
#  <a href="/about/exec.php">Executive Council</a>,
#  <a href="/about/history.php">History</a>,
#  <a href="/about/reports.php">Annual Reports</a>,
#  <a href="/contact_JPL.php">Contact Us</a>,
#  <a href="/opportunities/">Opportunities</a>,
#  <a href="https://thejplstore.com" target="_blank">JPL Online Store</a>,
#  <a href="/acquisition/">Doing Business with JPL</a>,
#  <a href="/missions/?type=current">Current</a>,
#  <a href="/missions/?type=past">Past</a>,
#  <a href="/missions/?type=future">Future</a>,
#  <a href="/missions/?type=proposed">Proposed</a>,
#  <a href="/missions">All</a>,
#  <a href="/edu/intern/">Intern</a>,
#  <a href="/edu/learn/">Learn</a>,
#  <a href="/edu/teach/">Teach</a>,
#  <a href="/edu/news/">News</a>,
#  <a href="/edu/events/">Events</a>,
#  <a href="https://spaceplace.nasa.gov/menu/play/">Games</a>,
#  <a href="/news">Latest News</a>,
#  <a href="/news/presskits.php">Press Kits</a>,
#  <a href="/news/factsheets.php">Fact Sheets</a>,
#  <a href="/news/mediainformation.php">Media Information</a>,
#  <a href="/universe/">Universe Newspaper</a>,
#  <a href="/events/">Overview</a>,
#  <a href="/events/tours/views/">Tours</a>,
#  <a href="/events/lectures.php">Lecture Series</a>,
#  <a href="/events/speakers-bureau.php">Speakers Bureau</a>,
#  <a href="/events/team-competitions.php">Team Competitions</a>,
#  <a href="/events/special-events.php">Special Events</a>,
#  <a href="/asteroidwatch/">Asteroid Watch</a>,
#  <a href="https://solarsystem.nasa.gov/basics/" target="_blank">Basics of Spaceflight
#                        </a>,
#  <a href="https://solarsystem.nasa.gov/basics/" target="_blank">
#  </a>,
#  <a href="https://solarsystem.nasa.gov/basics/" target="_blank">
#  </a>,
#  <a href="http://saturn.jpl.nasa.gov/index.cfm">Cassini - Mission to Saturn</a>,
#  <a href="http://climate.nasa.gov">Earth / Global Climate Change</a>,
#  <a href="http://planetquest.jpl.nasa.gov">Exoplanet Exploration</a>,
#  <a href="/missions/juno/">Juno - Mission to Jupiter</a>,
#  <a href="https://mars.nasa.gov/">Mars Exploration</a>,
#  <a href="http://scienceandtechnology.jpl.nasa.gov/">Science and Technology</a>,
#  <a href="http://solarsystem.nasa.gov/">Solar System Exploration</a>,
#  <a href="https://eyes.nasa.gov/">NASA's Eyes</a>,
#  <a href="http://www.spitzer.caltech.edu/">Spitzer Space Telescope</a>,
#  <a href="https://voyager.jpl.nasa.gov/">Voyager Interstellar Mission</a>,
#  <a href="/spaceimages/">JPL Space Images</a>,
#  <a href="/video/">Videos</a>,
#  <a href="/infographics/">Infographics</a>,
#  <a href="https://photojournal.jpl.nasa.gov/">Photojournal</a>,
#  <a href="http://www.nasaimages.org/">NASA Images</a>,
#  <a href="/apps/">Mobile Apps</a>,
#  <a href="/signup/">Newsletter</a>,
#  <a href="https://www.facebook.com/NASAJPL">Facebook</a>,
#  <a href="http://twitter.com/NASAJPL">Twitter</a>,
#  <a href="http://www.youtube.com/user/JPLnews">YouTube</a>,
#  <a href="http://www.flickr.com/photos/nasa-jpl">Flickr</a>,
#  <a href="http://instagram.com/nasajpl">Instagram</a>,
#  <a href="https://www.linkedin.com/company/2004/">LinkedIn</a>,
#  <a href="http://itunes.apple.com/podcast/hd-nasas-jet-propulsion-laboratory/id262254981">iTunes</a>,
#  <a href="http://www.ustream.tv/nasajpl">UStream</a>,
#  <a href="/rss/">RSS</a>,
#  <a href="http://blogs.jpl.nasa.gov">Blog</a>,
#  <a href="/onthego/">Mobile</a>,
#  <a href="/social/">All Social Media</a>,
#  <a href="http://jplwater.nasa.gov">NASA Water Cleanup</a>,
#  <a href="http://www.hq.nasa.gov/office/pao/FOIA/agency/">FOIA</a>,
#  <a href="http://www.nasa.gov/" target="_blank">NASA</a>,
#  <a href="http://www.caltech.edu/" target="_blank">Caltech</a>,
#  <a href="/privacy">Privacy</a>,
#  <a href="/imagepolicy">Image Policy</a>,
#  <a href="/faq.php">FAQ</a>,
#  <a href="/contact_JPL.php">Feedback</a>]

# %%
mydivs = soup.find("div", {"class": "article_teaser_body"})
mydivs
# Out:
# <div class="article_teaser_body">March 2, 2020</div>

# %%
paragraphs = soup.find_all('p')
for paragraph in paragraphs:
    print(paragraph.text)
# Out:
# Managed by the Mars Exploration Program and the Jet Propulsion Laboratory for NASA’s Science Mission Directorate

# %%
#PL Mars Space Images - Featured Image
#Visit the url for JPL Featured Space Image here.
#Use splinter to navigate the site and find the image url for the current Featured Mars Image and assign the url string to a variable called featured_image_url.
#Make sure to find the image url to the full size .jpg image.
#Make sure to save a complete url string for this image.
# Example:
featured_image_url = 'https://www.jpl.nasa.gov/spaceimages/images/largesize/PIA16225_hires.jpg'

# %%
# https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
 url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(url)

# %%
for x in range(1, 6):

    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')

    quotes = soup.find_all('span', id_='images')

    src = browser.find_by_id('recaptcha_challenge_image')['src']
    script = "document.getElementById('recaptcha_challenge_image').src"
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/splinter/driver/webdriver/__init__.py:528: FutureWarning: browser.find_link_by_partial_text is deprecated. Use browser.links.find_by_partial_text instead.
#   FutureWarning,
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/splinter/element_list.py in __getitem__(self, index)
#      41         try:
# ---> 42             return self._container[index]
#      43         except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ElementDoesNotExist                       Traceback (most recent call last)
# <ipython-input-42-e5e1ff22f088> in <module>
#      10         print(quote.text)
#      11
# ---> 12     browser.click_link_by_partial_text('Next')
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/splinter/driver/__init__.py in click_link_by_partial_text(self, partial_text)
#     394         Clicks in a link by partial content of its text.
#     395         """
# --> 396         return self.find_link_by_partial_text(partial_text).first.click()
#     397
#     398     def click_link_by_id(self, id):
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/splinter/element_list.py in first(self)
#      55             >>> assert element_list[0] == element_list.first
#      56         """
# ---> 57         return self[0]
#      58
#      59     @property
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/splinter/element_list.py in __getitem__(self, index)
#      44             raise ElementDoesNotExist(
#      45                 u'no elements could be found with {0} "{1}"'.format(
# ---> 46                     self.find_by, self.query
#      47                 )
#      48             )
#
# ElementDoesNotExist: no elements could be found with link by partial text "Next"

# %%
#Mars Weather
#Visit the Mars Weather twitter account here and scrape the latest Mars weather tweet from the page. Save the tweet text for the weather report as a variable called mars_weather.
#Note: Be sure you are not signed in to twitter, or scraping may become more difficult.
# Example:
mars_weather = 'Sol 1801 (Aug 30, 2017), Sunny, high -21C/-5F, low -80C/-112F, pressure at 8.82 hPa, daylight 06:09-17:55'

# %%
https://twitter.com/marswxreport?lang=en

# %%
#Mars Facts
#Visit the Mars Facts webpage here and use Pandas to scrape the table containing facts about the planet including Diameter, Mass, etc.
#Use Pandas to convert the data to a HTML table string.

# %%
url1= 'https://space-facts.com/mars/'

# %%
# Use Panda's `read_html` to parse the url
### BEGIN SOLUTION
tables = pd.read_html(url1)
tables
### END SOLUTION
# Out:
# [                      0                              1
#  0  Equatorial Diameter:                       6,792 km
#  1       Polar Diameter:                       6,752 km
#  2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
#  3                Moons:            2 (Phobos & Deimos)
#  4       Orbit Distance:       227,943,824 km (1.38 AU)
#  5         Orbit Period:           687 days (1.9 years)
#  6  Surface Temperature:                   -87 to -5 °C
#  7         First Record:              2nd millennium BC
#  8          Recorded By:           Egyptian astronomers,
#    Mars - Earth Comparison             Mars            Earth
#  0               Diameter:         6,779 km        12,742 km
#  1                   Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
#  2                  Moons:                2                1
#  3      Distance from Sun:   227,943,824 km   149,598,262 km
#  4         Length of Year:   687 Earth days      365.24 days
#  5            Temperature:    -153 to 20 °C      -88 to 58°C,
#                        0                              1
#  0  Equatorial Diameter:                       6,792 km
#  1       Polar Diameter:                       6,752 km
#  2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
#  3                Moons:            2 (Phobos & Deimos)
#  4       Orbit Distance:       227,943,824 km (1.38 AU)
#  5         Orbit Period:           687 days (1.9 years)
#  6  Surface Temperature:                   -87 to -5 °C
#  7         First Record:              2nd millennium BC
#  8          Recorded By:           Egyptian astronomers]

# %%
#Mars Hemispheres
#Visit the USGS Astrogeology site here to obtain high resolution images for each of Mar's hemispheres.
#You will need to click each of the links to the hemispheres in order to find the image url to the full resolution image.
#Save both the image url string for the full resolution hemisphere image, and the Hemisphere title containing the hemisphere name. Use a Python dictionary to store the data using the keys img_url and title.
#Append the dictionary with the image url string and the hemisphere title to a list. This list will contain one dictionary for each hemisphere.
# Example:
hemisphere_image_urls = [
    {"title": "Valles Marineris Hemisphere", "img_url": "..."},
    {"title": "Cerberus Hemisphere", "img_url": "..."},
    {"title": "Schiaparelli Hemisphere", "img_url": "..."},
    {"title": "Syrtis Major Hemisphere", "img_url": "..."},
]

# %%
url2 = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'
tables2 = pd.read_html(url2)
tables2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-cc44e57a6967> in <module>
#       1 url2 = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'
# ----> 2 tables2 = pd.read_html(url2)
#       3 tables2
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     910             break
#     911     else:
# --> 912         raise_with_traceback(retained)
#     913
#     914     ret = []
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/compat/__init__.py in raise_with_traceback(exc, traceback)
#      45     if traceback == Ellipsis:
#      46         _, _, traceback = sys.exc_info()
# ---> 47     raise exc.with_traceback(traceback)
#      48
#      49
#
# ValueError: No tables found

# %%
Step 2 - MongoDB and Flask Application
Use MongoDB with Flask templating to create a new HTML page that displays all of the information that was scraped from the URLs above.


Start by converting your Jupyter notebook into a Python script called scrape_mars.py with a function called scrape that will execute all of your scraping code from above and return one Python dictionary containing all of the scraped data.


Next, create a route called /scrape that will import your scrape_mars.py script and call your scrape function.

Store the return value in Mongo as a Python dictionary.



Create a root route / that will query your Mongo database and pass the mars data into an HTML template to display the data.


Create a template HTML file called index.html that will take the mars data dictionary and display all of the data in the appropriate HTML elements. Use the following as a guide for what the final product should look like, but feel free to create your own design.

# %%
app = Flask(__name__)

# setup mongo connection
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# connect to mongo db and collection
db = client.store_inventory
produce = db.produce


@app.route("/")
def index():
    # write a statement that finds all the items in the db and sets it to a variable
    inventory = list(produce.find())
    print(inventory)

    # render an index.html template and pass it the data you retrieved from the database
    return render_template("index.html", inventory=inventory)


if __name__ == "__main__":
    app.run(debug=True)
